# %%
import numpy as np
import pandas as pd

# %%
 pip install -U scikit-learn scipy matplotlib

# %%
df1 = pd.read_csv('DrDoS_LDAP_new.csv')
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_21924\3717026788.py:1: DtypeWarning: Columns (80) have mixed types. Specify dtype option on import or set low_memory=False.
#   df1 = pd.read_csv('DrDoS_LDAP_new.csv')

# %%
df1.head()
# Out:
#     Source Port   Destination Port   Protocol   Flow Duration  \
# 0             0                  0          0         9141643
# 1           900               1808         17               1
# 2           900              58766         17               2
# 3           900              35228         17               1
# 4           900              44969         17               2
#
#     Total Fwd Packets   Total Backward Packets  Total Length of Fwd Packets  \
# 0               85894                       28                          0.0
# 1                   2                        0                       2944.0
# 2                   2                        0                       2944.0
# 3                   2                        0                       2944.0
# 4                   2                        0                       2944.0
#
#     Total Length of Bwd Packets   Fwd Packet Length Max  \
# 0                           0.0                     0.0
# ...

# %%
from sklearn import preprocessing
label_encoder = preprocessing.LabelEncoder()
df1[' Label']= label_encoder.fit_transform(df1[' Label'])
df1[' Label'].unique()
# Out:
# array([1, 0])

# %%
df1.head()
# Out:
#     Source Port   Destination Port   Protocol   Flow Duration  \
# 0             0                  0          0         9141643
# 1           900               1808         17               1
# 2           900              58766         17               2
# 3           900              35228         17               1
# 4           900              44969         17               2
#
#     Total Fwd Packets   Total Backward Packets  Total Length of Fwd Packets  \
# 0               85894                       28                          0.0
# 1                   2                        0                       2944.0
# 2                   2                        0                       2944.0
# 3                   2                        0                       2944.0
# 4                   2                        0                       2944.0
#
#     Total Length of Bwd Packets   Fwd Packet Length Max  \
# 0                           0.0                     0.0
# ...

# %%
l = []
for col in df1:
    
    try:
        if sum(df1[col]) == 0:
            l.append(col)
    except:
        print(col)
# Out:
# SimillarHTTP

# %%
l
# Out:
# [' Bwd PSH Flags',
#  ' Fwd URG Flags',
#  ' Bwd URG Flags',
#  'FIN Flag Count',
#  ' PSH Flag Count',
#  ' ECE Flag Count',
#  'Fwd Avg Bytes/Bulk',
#  ' Fwd Avg Packets/Bulk',
#  ' Fwd Avg Bulk Rate',
#  ' Bwd Avg Bytes/Bulk',
#  ' Bwd Avg Packets/Bulk',
#  'Bwd Avg Bulk Rate',
#  ' Active Std',
#  ' Idle Std']

# %%
l
# Out:
# [' Bwd PSH Flags',
#  ' Fwd URG Flags',
#  ' Bwd URG Flags',
#  'FIN Flag Count',
#  ' PSH Flag Count',
#  ' ECE Flag Count',
#  'Fwd Avg Bytes/Bulk',
#  ' Fwd Avg Packets/Bulk',
#  ' Fwd Avg Bulk Rate',
#  ' Bwd Avg Bytes/Bulk',
#  ' Bwd Avg Packets/Bulk',
#  'Bwd Avg Bulk Rate',
#  ' Active Std',
#  ' Idle Std']

# %%
df1.drop(l, axis=1, inplace=True)

# %%
for col in df1:
    print(col)
# Out:
#  Source Port
#  Destination Port
#  Protocol
#  Flow Duration
#  Total Fwd Packets
#  Total Backward Packets
# Total Length of Fwd Packets
#  Total Length of Bwd Packets
#  Fwd Packet Length Max
#  Fwd Packet Length Min
#  Fwd Packet Length Mean
#  Fwd Packet Length Std
# Bwd Packet Length Max
#  Bwd Packet Length Min
#  Bwd Packet Length Mean
#  Bwd Packet Length Std
# Flow Bytes/s
#  Flow Packets/s
#  Flow IAT Mean
#  Flow IAT Std
#  Flow IAT Max
#  Flow IAT Min
# Fwd IAT Total
#  Fwd IAT Mean
#  Fwd IAT Std
#  Fwd IAT Max
#  Fwd IAT Min
# Bwd IAT Total
#  Bwd IAT Mean
#  Bwd IAT Std
#  Bwd IAT Max
#  Bwd IAT Min
# Fwd PSH Flags
#  Fwd Header Length
#  Bwd Header Length
# Fwd Packets/s
#  Bwd Packets/s
#  Min Packet Length
#  Max Packet Length
#  Packet Length Mean
#  Packet Length Std
#  Packet Length Variance
#  SYN Flag Count
#  RST Flag Count
#  ACK Flag Count
#  URG Flag Count
#  CWE Flag Count
#  Down/Up Ratio
#  Average Packet Size
#  Avg Fwd Segment Size
# ...

# %%
df1.head()
# Out:
#     Source Port   Destination Port   Protocol   Flow Duration  \
# 0             0                  0          0         9141643
# 1           900               1808         17               1
# 2           900              58766         17               2
# 3           900              35228         17               1
# 4           900              44969         17               2
#
#     Total Fwd Packets   Total Backward Packets  Total Length of Fwd Packets  \
# 0               85894                       28                          0.0
# 1                   2                        0                       2944.0
# 2                   2                        0                       2944.0
# 3                   2                        0                       2944.0
# 4                   2                        0                       2944.0
#
#     Total Length of Bwd Packets   Fwd Packet Length Max  \
# 0                           0.0                     0.0
# ...

# %%
df1[' Label']
# Out:
# 0          1
# 1          1
# 2          1
# 3          1
# 4          1
#           ..
# 2181537    1
# 2181538    1
# 2181539    1
# 2181540    1
# 2181541    1
# Name:  Label, Length: 2181542, dtype: int32

# %%
import matplotlib.pyplot as plt

# %%
no = df1[df1[' Label'] == 0]
yes = df1[df1[' Label'] == 1]
print(len(no), len(yes))
# Out:
# 1612 2179930

# %%
from sklearn.utils import resample

# no = df1[df1[' Label'] == 0]
# yes = df1[df1[' Label'] == 1]
no_oversampled = resample(no, replace=True, n_samples=len(yes), random_state=123)
df1 = pd.concat([yes, no_oversampled])


fig = plt.figure(figsize = (8,5))
df1[' Label'].value_counts(normalize = True).plot(kind='bar', color= ['skyblue','navy'], alpha = 0.9, rot=0)
# plt.title('DDOS ATTACK Indicator No(0) and Yes(1) after Oversampling ')
# plt.show()
# Out:
# <Axes: xlabel=' Label'>

# %%
no = df1[df1[' Label'] == 0]
yes = df1[df1[' Label'] == 1]
print(len(no), len(yes))
len(df1)
# Out:
# 2179930 2179930
# 4359860

# %%
df1.drop('SimillarHTTP', axis=1, inplace=True)

# %%
df1.head()
# Out:
#     Source Port   Destination Port   Protocol   Flow Duration  \
# 0             0                  0          0         9141643
# 1           900               1808         17               1
# 2           900              58766         17               2
# 3           900              35228         17               1
# 4           900              44969         17               2
#
#     Total Fwd Packets   Total Backward Packets  Total Length of Fwd Packets  \
# 0               85894                       28                          0.0
# 1                   2                        0                       2944.0
# 2                   2                        0                       2944.0
# 3                   2                        0                       2944.0
# 4                   2                        0                       2944.0
#
#     Total Length of Bwd Packets   Fwd Packet Length Max  \
# 0                           0.0                     0.0
# ...

# %%
len(df1)
# Out:
# 4359860

# %%
df1.describe()
# Out:
#         Source Port   Destination Port      Protocol   Flow Duration  \
# count  4.359860e+06       4.359860e+06  4.359860e+06    4.359860e+06
# mean   2.262962e+04       2.029558e+04  1.272118e+01    1.320372e+05
# std    2.770186e+04       2.289470e+04  5.768765e+00    7.077636e+05
# min    0.000000e+00       0.000000e+00  0.000000e+00    0.000000e+00
# 25%    6.750000e+02       8.000000e+01  6.000000e+00    1.000000e+00
# 50%    9.000000e+02       8.782000e+03  1.700000e+01    2.000000e+00
# 75%    5.724700e+04       4.153600e+04  1.700000e+01    2.088400e+04
# max    6.551000e+04       6.553500e+04  1.700000e+01    1.116618e+07
#
#         Total Fwd Packets   Total Backward Packets  \
# count        4.359860e+06             4.359860e+06
# mean         4.213007e+00             1.569721e+00
# std          3.288395e+02             6.636651e+00
# min          1.000000e+00             0.000000e+00
# 25%          2.000000e+00             0.000000e+00
# ...

# %%
#data = df1

# # Loop through each row and create a distribution plot
# for column in data.columns:
#     plt.figure(figsize=(6, 4))  # Adjust the figure size as needed
#     plt.hist(data[column], bins=100)  # You can adjust the number of bins as needed
#     plt.title(f'Distribution of {column}')
#     plt.xlabel('Value')
#     plt.ylabel('Frequency')
#     plt.show()

# %%
from sklearn.preprocessing import StandardScaler

# %%
# X = df1.drop(columns = ' Label', axis=1)
# Y = df1[' Label']

# %%
# scaler = StandardScaler()
# scaler.fit(X)
# standardized_data = scaler.transform(X)
# print(standardized_data)

# %%
# x = float("nan") - 1000000000000000000000000000
# float("inf") < float("inf")

# %%
# max_float64 = np.finfo(np.float64).max

# print(max_float64)

# %%
# for i in range(len(df1)):  
#     for j in range(len(df1.columns)):  
#          df1.iloc[i, j] = df1.iloc[i, j]/10000

# %%
df1.replace([np.inf, -np.inf], np.nan, inplace=True)
df1.dropna(inplace=True)

# %%
print(len(df1))
df1.sample(10)
# Out:
# 4294078
#           Source Port   Destination Port   Protocol   Flow Duration  \
# 1103129           443              59370          6               1
# 1183704         57249                 80          6           27969
# 1730715           916              18392         17               1
# 258025          51667                465          6           52569
# 683858          59386                443          6           62572
# 2164300           738              61568         17               1
# 1038511         57250                 80          6           28023
# 619406            990              23751         17               1
# 797535              0                  0          0               4
# 2024080         51678                 80          6           28372
#
#           Total Fwd Packets   Total Backward Packets  \
# 1103129                   2                        0
# 1183704                   2                        2
# ...

# %%
X = df1.drop(columns = ' Label', axis=1)
Y = df1[' Label']

# %%
print(X)
Y
# Out:
#           Source Port   Destination Port   Protocol   Flow Duration  \
# 0                   0                  0          0         9141643
# 1                 900               1808         17               1
# 2                 900              58766         17               2
# 3                 900              35228         17               1
# 4                 900              44969         17               2
# ...               ...                ...        ...             ...
# 1736409         64507                 53         17           50055
# 1742835         54494                 53         17           20595
# 1456909         59421                443          6               1
# 1529812         59396                443          6          151741
# 2070128         59426                443          6             624
#
#           Total Fwd Packets   Total Backward Packets  \
# 0                     85894                       28
# ...

# %%
scaler = StandardScaler()
scaler.fit(X)
standardized_data = scaler.transform(X)
print(standardized_data)
# Out:
# [[-0.819926   -0.88429985 -2.20694882 ...  0.02208811 -0.45189814
#   -1.82843941]
#  [-0.78746845 -0.80530041  0.74162557 ...  0.02208811 -0.45189814
#   -1.82843578]
#  [-0.78746845  1.68344415  0.74162557 ...  0.02208811 -0.45189814
#   -1.82843451]
#  ...
#  [ 1.32302993 -0.86494324 -1.16627551 ... -0.79114607  0.12020069
#    0.55204231]
#  [ 1.32212833 -0.86494324 -1.16627551 ... -0.89540686  2.8940132
#    0.6814636 ]
#  [ 1.32321025 -0.86494324 -1.16627551 ... -0.79114607  0.18954601
#    1.60463981]]

# %%
print(X)
Y
# Out:
#           Source Port   Destination Port   Protocol   Flow Duration  \
# 0                   0                  0          0         9141643
# 1                 900               1808         17               1
# 2                 900              58766         17               2
# 3                 900              35228         17               1
# 4                 900              44969         17               2
# ...               ...                ...        ...             ...
# 1736409         64507                 53         17           50055
# 1742835         54494                 53         17           20595
# 1456909         59421                443          6               1
# 1529812         59396                443          6          151741
# 2070128         59426                443          6             624
#
#           Total Fwd Packets   Total Backward Packets  \
# 0                     85894                       28
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.5, stratify=Y, random_state=2)

# %%
print(X.shape, X_train.shape, X_test.shape)
# Out:
# (4294078, 76) (2147039, 76) (2147039, 76)

# %%
model = LogisticRegression()

# %%
model.fit(X_train, Y_train)
# Out:
# C:\Users\User\miniconda3\envs\tf\Lib\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
from sklearn.metrics import accuracy_score

# %%
X_train_prediction = model.predict(X_train)
training_data_accuracy = accuracy_score(X_train_prediction, Y_train)

# %%
print('Accuracy on Training data : ', training_data_accuracy)
# Out:
# Accuracy on Training data :  0.9995100228733619

# %%
X_test_prediction = model.predict(X_test)
test_data_accuracy = accuracy_score(X_test_prediction, Y_test)

# %%
print('Accuracy on Test data : ', test_data_accuracy)
# Out:
# Accuracy on Test data :  0.9995505437954317

# %%
import random
# n = random.randint(0,22)

# %%
# dfx = pd.read_csv('DrDoS_LDAP_new.csv')

# %%
specific_row = list(df1.iloc[random.randint(0,len(df1))])
print(specific_row[-10])
del specific_row[-10]
# Out:
# 1.0

# %%
input_data = specific_row

# change the input data to a numpy array
input_data_as_numpy_array= np.asarray(input_data)

# reshape the numpy array as we are predicting for only on instance
input_data_reshaped = input_data_as_numpy_array.reshape(1,-1)

prediction = model.predict(input_data_reshaped)
print(prediction)

if (prediction[0]== 1):
  print('The Person  have a attack')
else:
  print('The Person not attack')
# Out:
# [1]
# The Person  have a attack
# C:\Users\User\miniconda3\envs\tf\Lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
model = RandomForestClassifier()

# %%
model.fit(X_train, Y_train)
# Out:
# RandomForestClassifier()

# %%
X_test_prediction1 = model.predict(X_test)
test_data_accuracy1 = accuracy_score(X_test_prediction1, Y_test)

# %%
print('Accuracy : ', test_data_accuracy1)
# Out:
# Accuracy :  1.0

# %%
X_train_prediction1 = model.predict(X_train)
training_data_accuracy1 = accuracy_score(X_train_prediction1, Y_train)

# %%
print('Accuracy on Training data : ', training_data_accuracy1)
# Out:
# Accuracy on Training data :  1.0

# %%
from sklearn.neighbors import KNeighborsClassifier  
classifier= KNeighborsClassifier(n_neighbors=5, metric='minkowski', p=2 )  
classifier.fit(X_train, Y_train)
# Out:
# KNeighborsClassifier()

# %%
y_pred= classifier.predict(X_test)

# %%
test_data_accuracy1 = accuracy_score(y_pred, Y_test)

# %%
print('Accuracy : ', test_data_accuracy1)
