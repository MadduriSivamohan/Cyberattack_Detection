# %%
import numpy as np
import pandas as pd

# %%
df1 = pd.read_csv('DrDoS_DNS_new.csv')
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_2540\1656711912.py:1: DtypeWarning: Columns (80) have mixed types. Specify dtype option on import or set low_memory=False.
#   df1 = pd.read_csv('DrDoS_DNS_new.csv')

# %%
df1.drop('SimillarHTTP', axis=1, inplace=True)
df1.drop(' Fwd Packet Length Max', axis=1, inplace=True)
df1.drop(' Fwd Packet Length Min', axis=1, inplace=True)
df1.drop('Bwd Packet Length Max', axis=1, inplace=True)
df1.drop(' Bwd Packet Length Min', axis=1, inplace=True)
df1.drop(' Flow IAT Max', axis=1, inplace=True)
df1.drop(' Flow IAT Min', axis=1, inplace=True)
df1.drop(' Fwd IAT Max', axis=1, inplace=True)
df1.drop(' Fwd IAT Min', axis=1, inplace=True)
df1.drop(' Bwd IAT Max', axis=1, inplace=True)
df1.drop(' Bwd IAT Min', axis=1, inplace=True)
df1.drop(' Idle Max', axis=1, inplace=True)
df1.drop(' Idle Min', axis=1, inplace=True)
df1.drop(' Active Max', axis=1, inplace=True)
df1.drop(' Active Min', axis=1, inplace=True)

# %%
df2 = pd.read_csv('DrDoS_LDAP_new.csv')
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_2540\3028507185.py:1: DtypeWarning: Columns (80) have mixed types. Specify dtype option on import or set low_memory=False.
#   df2 = pd.read_csv('DrDoS_LDAP_new.csv')

# %%
df2.drop('SimillarHTTP', axis=1, inplace=True)
df2.drop(' Fwd Packet Length Max', axis=1, inplace=True)
df2.drop(' Fwd Packet Length Min', axis=1, inplace=True)
df2.drop('Bwd Packet Length Max', axis=1, inplace=True)
df2.drop(' Bwd Packet Length Min', axis=1, inplace=True)
df2.drop(' Flow IAT Max', axis=1, inplace=True)
df2.drop(' Flow IAT Min', axis=1, inplace=True)
df2.drop(' Fwd IAT Max', axis=1, inplace=True)
df2.drop(' Fwd IAT Min', axis=1, inplace=True)
df2.drop(' Bwd IAT Max', axis=1, inplace=True)
df2.drop(' Bwd IAT Min', axis=1, inplace=True)
df2.drop(' Idle Max', axis=1, inplace=True)
df2.drop(' Idle Min', axis=1, inplace=True)
df2.drop(' Active Max', axis=1, inplace=True)
df2.drop(' Active Min', axis=1, inplace=True)

# %%
df = pd.concat([df1,df2])
del df1, df2

# %%
df3 = pd.read_csv('DrDoS_MSSQL_new.csv')
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_2540\1792751016.py:1: DtypeWarning: Columns (80) have mixed types. Specify dtype option on import or set low_memory=False.
#   df3 = pd.read_csv('DrDoS_MSSQL_new.csv')

# %%
df3.drop('SimillarHTTP', axis=1, inplace=True)
df3.drop(' Fwd Packet Length Max', axis=1, inplace=True)
df3.drop(' Fwd Packet Length Min', axis=1, inplace=True)
df3.drop('Bwd Packet Length Max', axis=1, inplace=True)
df3.drop(' Bwd Packet Length Min', axis=1, inplace=True)
df3.drop(' Flow IAT Max', axis=1, inplace=True)
df3.drop(' Flow IAT Min', axis=1, inplace=True)
df3.drop(' Fwd IAT Max', axis=1, inplace=True)
df3.drop(' Fwd IAT Min', axis=1, inplace=True)
df3.drop(' Bwd IAT Max', axis=1, inplace=True)
df3.drop(' Bwd IAT Min', axis=1, inplace=True)
df3.drop(' Idle Max', axis=1, inplace=True)
df3.drop(' Idle Min', axis=1, inplace=True)
df3.drop(' Active Max', axis=1, inplace=True)
df3.drop(' Active Min', axis=1, inplace=True)

# %%
df = pd.concat([df,df3])
del df3

# %%
df4 = pd.read_csv('DrDoS_NetBIOS_new.csv')
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_2540\3461573696.py:1: DtypeWarning: Columns (80) have mixed types. Specify dtype option on import or set low_memory=False.
#   df4 = pd.read_csv('DrDoS_NetBIOS_new.csv')

# %%
df4.drop('SimillarHTTP', axis=1, inplace=True)
df4.drop(' Fwd Packet Length Max', axis=1, inplace=True)
df4.drop(' Fwd Packet Length Min', axis=1, inplace=True)
df4.drop('Bwd Packet Length Max', axis=1, inplace=True)
df4.drop(' Bwd Packet Length Min', axis=1, inplace=True)
df4.drop(' Flow IAT Max', axis=1, inplace=True)
df4.drop(' Flow IAT Min', axis=1, inplace=True)
df4.drop(' Fwd IAT Max', axis=1, inplace=True)
df4.drop(' Fwd IAT Min', axis=1, inplace=True)
df4.drop(' Bwd IAT Max', axis=1, inplace=True)
df4.drop(' Bwd IAT Min', axis=1, inplace=True)
df4.drop(' Idle Max', axis=1, inplace=True)
df4.drop(' Idle Min', axis=1, inplace=True)
df4.drop(' Active Max', axis=1, inplace=True)
df4.drop(' Active Min', axis=1, inplace=True)

# %%
df = pd.concat([df,df4])
del df4

# %%
df5 = pd.read_csv('DrDoS_NTP_new.csv')
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_2540\4161238079.py:1: DtypeWarning: Columns (80) have mixed types. Specify dtype option on import or set low_memory=False.
#   df5 = pd.read_csv('DrDoS_NTP_new.csv')

# %%
df5.drop('SimillarHTTP', axis=1, inplace=True)
df5.drop(' Fwd Packet Length Max', axis=1, inplace=True)
df5.drop(' Fwd Packet Length Min', axis=1, inplace=True)
df5.drop('Bwd Packet Length Max', axis=1, inplace=True)
df5.drop(' Bwd Packet Length Min', axis=1, inplace=True)
df5.drop(' Flow IAT Max', axis=1, inplace=True)
df5.drop(' Flow IAT Min', axis=1, inplace=True)
df5.drop(' Fwd IAT Max', axis=1, inplace=True)
df5.drop(' Fwd IAT Min', axis=1, inplace=True)
df5.drop(' Bwd IAT Max', axis=1, inplace=True)
df5.drop(' Bwd IAT Min', axis=1, inplace=True)
df5.drop(' Idle Max', axis=1, inplace=True)
df5.drop(' Idle Min', axis=1, inplace=True)
df5.drop(' Active Max', axis=1, inplace=True)
df5.drop(' Active Min', axis=1, inplace=True)

# %%
df = pd.concat([df,df5])
del df5

# %%
df6 = pd.read_csv('DrDoS_SNMP_new.csv')
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_2540\3298748430.py:1: DtypeWarning: Columns (80) have mixed types. Specify dtype option on import or set low_memory=False.
#   df6 = pd.read_csv('DrDoS_SNMP_new.csv')

# %%
df6.drop('SimillarHTTP', axis=1, inplace=True)
df6.drop(' Fwd Packet Length Max', axis=1, inplace=True)
df6.drop(' Fwd Packet Length Min', axis=1, inplace=True)
df6.drop('Bwd Packet Length Max', axis=1, inplace=True)
df6.drop(' Bwd Packet Length Min', axis=1, inplace=True)
df6.drop(' Flow IAT Max', axis=1, inplace=True)
df6.drop(' Flow IAT Min', axis=1, inplace=True)
df6.drop(' Fwd IAT Max', axis=1, inplace=True)
df6.drop(' Fwd IAT Min', axis=1, inplace=True)
df6.drop(' Bwd IAT Max', axis=1, inplace=True)
df6.drop(' Bwd IAT Min', axis=1, inplace=True)
df6.drop(' Idle Max', axis=1, inplace=True)
df6.drop(' Idle Min', axis=1, inplace=True)
df6.drop(' Active Max', axis=1, inplace=True)
df6.drop(' Active Min', axis=1, inplace=True)

# %%
df = pd.concat([df,df6])
del df6

# %%
df7 = pd.read_csv('DrDoS_SSDP_new.csv')
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_2540\1114866959.py:1: DtypeWarning: Columns (80) have mixed types. Specify dtype option on import or set low_memory=False.
#   df7 = pd.read_csv('DrDoS_SSDP_new.csv')

# %%
df7.drop('SimillarHTTP', axis=1, inplace=True)
df7.drop(' Fwd Packet Length Max', axis=1, inplace=True)
df7.drop(' Fwd Packet Length Min', axis=1, inplace=True)
df7.drop('Bwd Packet Length Max', axis=1, inplace=True)
df7.drop(' Bwd Packet Length Min', axis=1, inplace=True)
df7.drop(' Flow IAT Max', axis=1, inplace=True)
df7.drop(' Flow IAT Min', axis=1, inplace=True)
df7.drop(' Fwd IAT Max', axis=1, inplace=True)
df7.drop(' Fwd IAT Min', axis=1, inplace=True)
df7.drop(' Bwd IAT Max', axis=1, inplace=True)
df7.drop(' Bwd IAT Min', axis=1, inplace=True)
df7.drop(' Idle Max', axis=1, inplace=True)
df7.drop(' Idle Min', axis=1, inplace=True)
df7.drop(' Active Max', axis=1, inplace=True)
df7.drop(' Active Min', axis=1, inplace=True)

# %%
df = pd.concat([df,df7])
del df7

# %%
df8 = pd.read_csv('DrDoS_UDP_new.csv')
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_2540\3264181376.py:1: DtypeWarning: Columns (80) have mixed types. Specify dtype option on import or set low_memory=False.
#   df8 = pd.read_csv('DrDoS_UDP_new.csv')

# %%
df8.drop('SimillarHTTP', axis=1, inplace=True)
df8.drop(' Fwd Packet Length Max', axis=1, inplace=True)
df8.drop(' Fwd Packet Length Min', axis=1, inplace=True)
df8.drop('Bwd Packet Length Max', axis=1, inplace=True)
df8.drop(' Bwd Packet Length Min', axis=1, inplace=True)
df8.drop(' Flow IAT Max', axis=1, inplace=True)
df8.drop(' Flow IAT Min', axis=1, inplace=True)
df8.drop(' Fwd IAT Max', axis=1, inplace=True)
df8.drop(' Fwd IAT Min', axis=1, inplace=True)
df8.drop(' Bwd IAT Max', axis=1, inplace=True)
df8.drop(' Bwd IAT Min', axis=1, inplace=True)
df8.drop(' Idle Max', axis=1, inplace=True)
df8.drop(' Idle Min', axis=1, inplace=True)
df8.drop(' Active Max', axis=1, inplace=True)
df8.drop(' Active Min', axis=1, inplace=True)

# %%
df = pd.concat([df,df8])
del df8

# %%
df9 = pd.read_csv('syn_new.csv')
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_2540\2026958325.py:1: DtypeWarning: Columns (80) have mixed types. Specify dtype option on import or set low_memory=False.
#   df9 = pd.read_csv('syn_new.csv')

# %%
df9.drop('SimillarHTTP', axis=1, inplace=True)
df9.drop(' Fwd Packet Length Max', axis=1, inplace=True)
df9.drop(' Fwd Packet Length Min', axis=1, inplace=True)
df9.drop('Bwd Packet Length Max', axis=1, inplace=True)
df9.drop(' Bwd Packet Length Min', axis=1, inplace=True)
df9.drop(' Flow IAT Max', axis=1, inplace=True)
df9.drop(' Flow IAT Min', axis=1, inplace=True)
df9.drop(' Fwd IAT Max', axis=1, inplace=True)
df9.drop(' Fwd IAT Min', axis=1, inplace=True)
df9.drop(' Bwd IAT Max', axis=1, inplace=True)
df9.drop(' Bwd IAT Min', axis=1, inplace=True)
df9.drop(' Idle Max', axis=1, inplace=True)
df9.drop(' Idle Min', axis=1, inplace=True)
df9.drop(' Active Max', axis=1, inplace=True)
df9.drop(' Active Min', axis=1, inplace=True)

# %%
df = pd.concat([df,df9])
del df9

# %%
df10 = pd.read_csv('UDPLag_new.csv')
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_2540\3541294946.py:1: DtypeWarning: Columns (80) have mixed types. Specify dtype option on import or set low_memory=False.
#   df10 = pd.read_csv('UDPLag_new.csv')

# %%
df10.drop('SimillarHTTP', axis=1, inplace=True)
df10.drop(' Fwd Packet Length Max', axis=1, inplace=True)
df10.drop(' Fwd Packet Length Min', axis=1, inplace=True)
df10.drop('Bwd Packet Length Max', axis=1, inplace=True)
df10.drop(' Bwd Packet Length Min', axis=1, inplace=True)
df10.drop(' Flow IAT Max', axis=1, inplace=True)
df10.drop(' Flow IAT Min', axis=1, inplace=True)
df10.drop(' Fwd IAT Max', axis=1, inplace=True)
df10.drop(' Fwd IAT Min', axis=1, inplace=True)
df10.drop(' Bwd IAT Max', axis=1, inplace=True)
df10.drop(' Bwd IAT Min', axis=1, inplace=True)
df10.drop(' Idle Max', axis=1, inplace=True)
df10.drop(' Idle Min', axis=1, inplace=True)
df10.drop(' Active Max', axis=1, inplace=True)
df10.drop(' Active Min', axis=1, inplace=True)

# %%
df = pd.concat([df,df10])
del df10

# %%
l = []
for col in df:
    
    try:
        if sum(df[col]) == 0:
            l.append(col)
    except:
        print(col)
# Out:
#  Label

# %%
l
# Out:
# [' Bwd PSH Flags',
#  ' Fwd URG Flags',
#  ' Bwd URG Flags',
#  'FIN Flag Count',
#  ' PSH Flag Count',
#  ' ECE Flag Count',
#  'Fwd Avg Bytes/Bulk',
#  ' Fwd Avg Packets/Bulk',
#  ' Fwd Avg Bulk Rate',
#  ' Bwd Avg Bytes/Bulk',
#  ' Bwd Avg Packets/Bulk',
#  'Bwd Avg Bulk Rate']

# %%
df.drop(l, axis=1, inplace=True)

# %%
print(len(df))
df.sample(10)
# Out:
# 29955285
#           Source Port   Destination Port   Protocol   Flow Duration  \
# 810143            749              16579         17              55
# 2212921         33856              50880         17               1
# 546542          53992              14949         17          108970
# 3948516           854              10174         17               3
# 4037663         21697              48626         17               1
# 3672949           688               6236         17               2
# 913670            980              56143         17               2
# 1299450         28373              22126          6               1
# 4220359         42038              19890         17               6
# 3443873           905               1713         17               1
#
#           Total Fwd Packets   Total Backward Packets  \
# 810143                   16                        0
# 2212921                   2                        0
# ...

# %%
df.replace([np.inf, -np.inf], np.nan, inplace=True)
df.dropna(inplace=True)
df
# Out:
#          Source Port   Destination Port   Protocol   Flow Duration  \
# 0                634              60495         17           28415
# 1                634              60495         17               2
# 2                634              46391         17           48549
# 3                634              11894         17           48337
# 4                634              27878         17           32026
# ...              ...                ...        ...             ...
# 370599         60489              27808          6               1
# 370600         60490              14102          6               1
# 370601         60491              58360          6               1
# 370602         60492               2905          6               2
# 370604         60494              44935          6             134
#
#          Total Fwd Packets   Total Backward Packets  \
# 0                       97                        0
# 1                        2                        0
# ...

# %%
df.to_csv('finalfile.csv', index=False)

# %%
# y_tmp=df[' Label'].values
# x=df.drop([' Label'], axis=1).values

# del df
# !free

# %%
# from collections import Counter

# %%
# import matplotlib.pyplot as plt

# %%
# sizes=[]
# labels=[]

# for i in Counter(y_tmp):
#     tmp=str(i)+' - '+str(Counter(y_tmp)[i])
#     labels.append(tmp)
#     sizes.append(Counter(y_tmp)[i])


# fig1, ax1 = plt.subplots(figsize = (9, 9))
# ax1.pie(sizes,  labels = labels) # 
# ax1.axis('equal')  
# plt.title('Class ratio')
# plt.legend()
# plt.show()

# %%
#set(y_tmp)

# %%
#!pip install imblearn

# %%
#from imblearn.pipeline import Pipeline
#from imblearn.over_sampling import SMOTE
#from imblearn.under_sampling import RandomUnderSampler
