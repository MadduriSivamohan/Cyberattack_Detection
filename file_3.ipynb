# %%
import numpy as np
import pandas as pd

# %%
df1 = pd.read_csv('DrDoS_DNS_new.csv')
df2 = pd.read_csv('DrDoS_LDAP_new.csv')
df = pd.concat([df1,df2])
del df1, df2
df3 = pd.read_csv('DrDoS_MSSQL_new.csv')
df = pd.concat([df,df3])
del df3
df4 = pd.read_csv('DrDoS_NetBIOS_new.csv')
df = pd.concat([df,df4])
del df4
df5 = pd.read_csv('DrDoS_NTP_new.csv')
df = pd.concat([df,df5])
del df5
df6 = pd.read_csv('DrDoS_SNMP_new.csv')
df = pd.concat([df,df6])
del df6
df7 = pd.read_csv('DrDoS_SSDP_new.csv')
df = pd.concat([df,df7])
del df7
df8 = pd.read_csv('DrDoS_UDP_new.csv')
df = pd.concat([df,df8])
del df8
df9 = pd.read_csv('syn_new.csv')
df = pd.concat([df,df9])
del df9
df10 = pd.read_csv('UDPLag_new.csv')
df = pd.concat([df,df10])
del df10
# df = pd.concat([df1,df2])
# df = pd.concat([df,df3])
# df = pd.concat([df,df4])
# df = pd.concat([df,df5])
# df = pd.concat([df,df6])
# df = pd.concat([df,df7])
# df = pd.concat([df,df8])
# del df1,df2,df3,df4,df5,df6,df7,df8

# len(df)
# df.sample(10)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_21084\1735180685.py:1: DtypeWarning: Columns (80) have mixed types. Specify dtype option on import or set low_memory=False.
#   df1 = pd.read_csv('DrDoS_DNS_new.csv')
# C:\Users\User\AppData\Local\Temp\ipykernel_21084\1735180685.py:2: DtypeWarning: Columns (80) have mixed types. Specify dtype option on import or set low_memory=False.
#   df2 = pd.read_csv('DrDoS_LDAP_new.csv')
# C:\Users\User\AppData\Local\Temp\ipykernel_21084\1735180685.py:5: DtypeWarning: Columns (80) have mixed types. Specify dtype option on import or set low_memory=False.
#   df3 = pd.read_csv('DrDoS_MSSQL_new.csv')
# C:\Users\User\AppData\Local\Temp\ipykernel_21084\1735180685.py:8: DtypeWarning: Columns (80) have mixed types. Specify dtype option on import or set low_memory=False.
#   df4 = pd.read_csv('DrDoS_NetBIOS_new.csv')
# ...

# %%
len(df)
df.sample(10)
# Out:
#           Source Port   Destination Port   Protocol   Flow Duration  \
# 4467480           564              38590         17               1
# 260919            713              31844         17               1
# 2468598           913               3410         17               2
# 2169489           946              36870         17               1
# 896836          46528               7775          6               0
# 2323095           785              28380         17               1
# 3983148         41775              26192         17               1
# 2648296           564              57013         17               1
# 3106956         56367              12344         17               1
# 484388          50200              18859         17          105765
#
#           Total Fwd Packets   Total Backward Packets  \
# 4467480                   2                        0
# 260919                    2                        0
# 2468598                   2                        0
# ...

# %%
df.drop('SimillarHTTP', axis=1, inplace=True)

# %%
l = []
for col in df:
    
    try:
        if sum(df[col]) == 0:
            l.append(col)
    except:
        print(col)
# Out:
#  Label

# %%
df.drop(l, axis=1, inplace=True)

# %%
l
# Out:
# [' Bwd PSH Flags',
#  ' Fwd URG Flags',
#  ' Bwd URG Flags',
#  'FIN Flag Count',
#  ' PSH Flag Count',
#  ' ECE Flag Count',
#  'Fwd Avg Bytes/Bulk',
#  ' Fwd Avg Packets/Bulk',
#  ' Fwd Avg Bulk Rate',
#  ' Bwd Avg Bytes/Bulk',
#  ' Bwd Avg Packets/Bulk',
#  'Bwd Avg Bulk Rate']

# %%
df.head()
# Out:
#     Source Port   Destination Port   Protocol   Flow Duration  \
# 0           634              60495         17           28415
# 1           634              60495         17               2
# 2           634              46391         17           48549
# 3           634              11894         17           48337
# 4           634              27878         17           32026
#
#     Total Fwd Packets   Total Backward Packets  Total Length of Fwd Packets  \
# 0                  97                        0                      42680.0
# 1                   2                        0                        880.0
# 2                 200                        0                      88000.0
# 3                 200                        0                      88000.0
# 4                 200                        0                      88000.0
#
#     Total Length of Bwd Packets   Fwd Packet Length Max  \
# 0                           0.0                   440.0
# ...

# %%
df.replace([np.inf, -np.inf], np.nan, inplace=True)
df.dropna(inplace=True)
df
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[10], line 2
#       1 df.replace([np.inf, -np.inf], np.nan, inplace=True)
# ----> 2 df.dropna(inplace=True)
#       3 df
#
# File ~\miniconda3\envs\tf\Lib\site-packages\pandas\core\frame.py:6425, in DataFrame.dropna(self, axis, how, thresh, subset, inplace, ignore_index)
#    6423     result = self.copy(deep=None)
#    6424 else:
# -> 6425     result = self.loc(axis=axis)[mask]
#    6427 if ignore_index:
#    6428     result.index = default_index(len(result))
#
# File ~\miniconda3\envs\tf\Lib\site-packages\pandas\core\indexing.py:1103, in _LocationIndexer.__getitem__(self, key)
#    1100 axis = self.axis or 0
#    1102 maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1103 return self._getitem_axis(maybe_callable, axis=axis)
#
# ...
